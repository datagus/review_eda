# %%
import pandas as pd
import json
from pybliometrics.scopus import AbstractRetrieval, AuthorRetrieval, AffiliationRetrieval
import warnings
import datetime

# %%
## Load configuration
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# %% [markdown]
# ## Importing excel sheet from Google Drive

# %%
#importing and opening file
url_id = config['url_id']
url_base = "https://docs.google.com/spreadsheets/d/"
url_e = "export/format=xlsx"
file = pd.ExcelFile(f"{url_base}{url_id}{url_e}")  
with pd.ExcelFile(file) as xls:  
    df = pd.read_excel(xls, "cleaner table", header=0)
    
#ignoring warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, message=".*utcnow.*")
now = datetime.datetime.utcnow()


#removing blank columns
df = df.iloc[:,:44]
#removing useless columns for analysis
columns_to_drop = ["Author(s) ID", "Volume", "Issue", "Art. No.", 
                   "Page start", "Page end", "Page count", 
                   "Link", "Index Keywords", "Document Type", 
                   "Publication Stage", "Open Access", "Source"]
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855 entries, 0 to 854
# Data columns (total 31 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Authors                                  855 non-null    object
#  1   Author full names                        843 non-null    object
#  2   Title                                    854 non-null    object
#  3   Year                                     855 non-null    int64
#  4   Source title                             855 non-null    object
#  5   Cited by                                 855 non-null    int64
#  6   DOI                                      849 non-null    object
#  7   Author Keywords                          613 non-null    object
#  8   Abstract                                 824 non-null    object
#  9   EID                                      855 non-null    object
#  10  SDG                                      855 non-null    int64
#  11  AI (yes/no)                              855 non-null    int64
#  12  Sustainability (yes/no)                  855 non-null    int64
#  13  Type of AI                               855 non-null    object
#  14  Algorithm(s) used                        852 non-null    object
#  15  Method (1) vs. study object (2)          849 non-null    object
#  16  AI as buzzword? (0/1)                    855 non-null    int64
#  17  Core topic                               855 non-null    object
#  18  Role of AI                               577 non-null    object
#  19  Means (1) vs. end (2)                    849 non-null    object
#  20  sustainability definition                419 non-null    object
#  21  Sus_lvl                                  855 non-null    object
#  22  empirical/conceptual/review              855 non-null    object
#  23  spatial scale                            455 non-null    object
#  24  snapshot in time vs. longitudinal study  518 non-null    object
#  25  temporal scale (past, present, future)   522 non-null    object
#  26  qualitative/quantitative/mixed methods   525 non-null    object
#  27  location of the study (country)          368 non-null    object
#  28  dataset used                             443 non-null    object
#  29  first_author_country                     855 non-null    object
#  30  policy recommendations (1/0)             855 non-null    int64
# dtypes: int64(7), object(24)
# memory usage: 207.2+ KB

# %% [markdown]
# ## Authors dataframe

# %%
#creating the function
def articles_info(eids):
    arts = []
    for eid in eids:
        #applying pybliometrics
        arts.append(AbstractRetrieval(eid, view='FULL'))
    return arts

# %%
#extracting all the eid's and scopus id's
eids = df["EID"].tolist()
#calling the function, make sure to have your API key running
articles = articles_info(eids)

# %%
#creating dictionary
authors = {
            'article_eid': [],
            'author_id': [],
            'author_name': [],
            'affiliation_country': [],
            'position in article': []
            }
#iterating over each element in the articles list
for article in articles:
    #iterating over each element in authorgroup
    for i in range(len(article.authorgroup)):
        authors['article_eid'].append(article.eid)
        authors['author_id'].append(article.authorgroup[i].auid)
        first_name = article.authorgroup[i].given_name
        last_name = article.authorgroup[i].surname
        authors['author_name'].append(f'{first_name} {last_name}')
        authors['affiliation_country'].append(article.authorgroup[i].country)
        authors['position in article'].append(str(i+1))

authors_df = pd.DataFrame(authors)

# %%
authors_df.loc[authors_df["position in article"]=="1",]
# Out:
#              article_eid    author_id           author_name  \
# 0     2-s2.0-85091803788  56319399400         Scott Thiebes
# 3     2-s2.0-85089383999  57218510909           Juin-Hao Ho
# 6     2-s2.0-85128853821  56512092600       Marius Bartmann
# 7     2-s2.0-85127588032  57562370000      Aurélie Halsband
# 8     2-s2.0-85177554926  36618183700           Raghu Raman
# ...                  ...          ...                   ...
# 6361  2-s2.0-85128453304  57580812100          Jiyoung Jang
# 6363  2-s2.0-85174748358  57205140187  Johnblack K. Kabukye
# 6376  2-s2.0-85171645006  58606568400          Meizhen Deng
# 6379  2-s2.0-85160969682  58221931100            Xingce Zhu
# 6388  2-s2.0-85122722865  55331174600       Valentin Kuleto
#
#      affiliation_country position in article
# 0                Germany                   1
# 3                 Taiwan                   1
# 6                Germany                   1
# 7                Germany                   1
# 8                  India                   1
# ...                  ...                 ...
# 6361         South Korea                   1
# 6363              Sweden                   1
# 6376               China                   1
# 6379               China                   1
# 6388              Serbia                   1
#
# [856 rows x 5 columns]

# %% [markdown]
# ## Converting columns to boolean

# %%
columns_to_boolean = ["AI (yes/no)", 
            "Sustainability (yes/no)", 
            "AI as buzzword? (0/1)",
            "policy recommendations (1/0)"]

# %%
df[columns_to_boolean] = df[columns_to_boolean].astype('bool')

# %% [markdown]
# ## Metadataframe

# %%
metadata_df = df.loc[:,["EID", "Title", "Year",
                        "SDG", "Source title", 
                        "Cited by", "DOI", 
                        "Abstract", "Author Keywords", 
                        "AI (yes/no)", "Sustainability (yes/no)" ]]
metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855 entries, 0 to 854
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EID                      855 non-null    object
#  1   Title                    854 non-null    object
#  2   Year                     855 non-null    int64
#  3   SDG                      855 non-null    int64
#  4   Source title             855 non-null    object
#  5   Cited by                 855 non-null    int64
#  6   DOI                      849 non-null    object
#  7   Abstract                 824 non-null    object
#  8   Author Keywords          613 non-null    object
#  9   AI (yes/no)              855 non-null    bool
#  10  Sustainability (yes/no)  855 non-null    bool
# dtypes: bool(2), int64(3), object(6)
# memory usage: 61.9+ KB

# %% [markdown]
# ## Function to separate values in the same cell

# %%
def separating(df, old_column, new_column):
    df[new_column] = df[old_column].str.split(';')
    df = df.explode(new_column)
    df = df.drop(columns=old_column).reset_index(drop=True)
    df[new_column] = df[new_column].str.strip()
    df[new_column] = df[new_column].str.lower()
    return df

# %% [markdown]
# ## AI_type dataframe

# %%
ai_df = df.loc[:, ["EID", "Type of AI"]]
aitype_df = separating(ai_df, "Type of AI", "AI_type")
aitype_df
# Out:
#                      EID                        AI_type
# 0     2-s2.0-85091803788                        overall
# 1     2-s2.0-85089383999                        overall
# 2     2-s2.0-85128853821                        overall
# 3     2-s2.0-85127588032                        overall
# 4     2-s2.0-85177554926                            nlp
# ...                  ...                            ...
# 1054  2-s2.0-85174748358               machine learning
# 1055  2-s2.0-85171645006  unsupervised machine learning
# 1056  2-s2.0-85171645006                            nlp
# 1057  2-s2.0-85171645006                  deep learning
# 1058  2-s2.0-85160969682                        overall
#
# [1059 rows x 2 columns]

# %%
dff = aitype_df.drop_duplicates(subset=["EID"]).reset_index(drop=True)
dff
# Out:
#                     EID                        AI_type
# 0    2-s2.0-85091803788                        overall
# 1    2-s2.0-85089383999                        overall
# 2    2-s2.0-85128853821                        overall
# 3    2-s2.0-85127588032                        overall
# 4    2-s2.0-85177554926                            nlp
# ..                  ...                            ...
# 850  2-s2.0-85099138027                        overall
# 851  2-s2.0-85128453304                        overall
# 852  2-s2.0-85174748358               machine learning
# 853  2-s2.0-85171645006  unsupervised machine learning
# 854  2-s2.0-85160969682                        overall
#
# [855 rows x 2 columns]

# %%
dff.loc[dff["AI_type"] == "blockchain",]
# Out:
# Empty DataFrame
# Columns: [EID, AI_type]
# Index: []

# %%
dff["AI_type"].unique()
# Out:
# array(['overall', 'nlp', 'deep learning', 'machine learning',
#        'supervised machine learning', 'idss',
#        'unsupervised machine learning', 'evolutionary algorithms',
#        'fuzzy logic', 'google earth engine', 'reinforcement learning',
#        'symbolic ai', 'mas', 'edge ai', 'mcdm ai', 'eai', 'llm',
#        'geospatial ai', 'generative ai', 'quantum ai', 'explainable ai'],
#       dtype=object)

# %% [markdown]
# ## Algorithms dataframe

# %%
a_df = df.loc[:, ["EID", "Algorithm(s) used"]]
algo_df = separating(a_df, "Algorithm(s) used", "Algorithms")
algo_df = algo_df.sort_values(by="Algorithms", ascending=True).reset_index(drop=True)

# %%
algo_df
# Out:
#                      EID Algorithms
# 0     2-s2.0-85121255385        aaa
# 1     2-s2.0-85102000803      ablwl
# 2     2-s2.0-85042656860        aco
# 3     2-s2.0-85038906891        aco
# 4     2-s2.0-85084937718        aco
# ...                  ...        ...
# 1189  2-s2.0-85150761407      xlnet
# 1190  2-s2.0-85111814672        xyf
# 1191  2-s2.0-85133863118       yolo
# 1192  2-s2.0-85146707006       yolo
# 1193  2-s2.0-85127551777      zfnet
#
# [1194 rows x 2 columns]

# %%
algo_df.loc[algo_df["Algorithms"].isnull(),]
# Out:
# Empty DataFrame
# Columns: [EID, Algorithms]
# Index: []

# %%
temp_array = algo_df["Algorithms"].unique()

# %%
temp_array
# Out:
# array(['aaa', 'ablwl', 'aco', 'adaboost', 'adam optimizer', 'aeba',
#        'anfis', 'ann', 'ap', 'ba', 'bayesian algorithm', 'bbo', 'bert',
#        'blwl', 'bn', 'bnm', 'bpit', 'bpnn', 'bra', 'brt', 'canfis',
#        'cart', 'catboost', 'ccnn', 'cdrm', 'ceda', 'cgda', 'cgpb',
#        'chatbots', 'chatgpt', 'cma-es', 'cnn', 'cpann', 'crm',
#        'cultural algorithm', 'dbm', 'dbscan', 'ddqn', 'de',
#        'decision tree', 'dexined', 'dnn', 'dpm', 'efo', 'elm', 'elnn',
#        'emla', 'enn', 'ensemble learning', 'ensemble nn', 'fa', 'fahp',
#        'fda', 'ffbp', 'fnn', 'fpd-smp-bal', 'frl', 'gan', 'garch',
#        'gaussian yolov3', 'gbfs', 'gbm', 'gdalbnn', 'genetic algorithm',
#        'genetic programming', 'gep', 'ggcn', 'gmdh', 'gmm', 'goa', 'gpr',
#        'gpt models', 'gpt-2', 'gpt3', 'grnn', 'gru', 'gtm', 'gwoa', 'gwr',
#        'harmony search', 'hierarchical clustering', 'hnn', 'hog',
#        'hybrid reasoning', 'ica', 'id3', 'isnn', 'iwo', 'joa', 'k-means',
#        'knn', 'knowledge graphs', 'lda', 'lightgbm', 'lime',
#        'linear regression', 'lma', 'logistic regression', 'lsaf', 'lsm',
#        'lsqb', 'lssvm', 'lstm', 'lstmrnn', 'mars', 'mblwl', 'mca', 'mcoa',
#        'mcs', 'mgrw', 'mha', 'mkca', 'mkl', 'mlc', 'mlp', 'mlr', 'mlstm',
#        'moga', 'mogo', 'moo', 'mpcnn', 'mpmr', 'mrmr', 'mtsc',
#        'multiple regression', 'munit', 'muzo', 'mvlr', 'n-beats', 'narx',
#        'nca', 'ncda', 'nltk', 'non-linear regression', 'nsga-ii',
#        'open ai models', 'overall', 'petri net', 'pls', 'pnn', 'prgbnn',
#        'psa', 'pso', 'q-learning', 'random forest', 'random tree', 'rbf',
#        'rbm', 'rbpp', 'rcf', 'rdf', 'regression algorithms',
#        'regression kriging', 'regression trees', 'relu', 'rf', 'rflwl',
#        'rmsd', 'rn', 'rnn', 'rvm', 'sce', 'scga', 'sfc', 'sfla', 'shap',
#        'shap-xgboost', 'sia', 'skn', 'slam', 'snn', 'som', 'sop',
#        'sslpnn', 'sso', 'stdn', 'svm', 'svr', 'swlr', 'swo', 'tcnn',
#        'tdnn', 'tlbom', 'topsis', 'tree boost', 'unspecified', 'various',
#        'vggnet', 'wdo', 'xgboost', 'xlnet', 'xyf', 'yolo', 'zfnet'],
#       dtype=object)

# %%
new_df = pd.DataFrame(temp_array, index=range(2, 2 + len(temp_array)))

# %%
new_df[179:len(temp_array)]
# Out:
#                           0
# 181                     svm
# 182                     svr
# 183  svr, xgboost, adaboost
# 184                    swlr
# 185                     tcn
# 186                    tcnn
# 187                    tdnn
# 188                   tlbom
# 189                  topsis
# 190               tree bost
# 191             unspecified
# 192                 various
# 193                  vggnet
# 194                     wdo
# 195                 xgboost
# 196                   xlnet
# 197                     xyf
# 198                    yolo
# 199                   zfnet
# 200                     NaN

# %%
url_id = config['url_id']
url_base = "https://docs.google.com/spreadsheets/d/"
url_e = "export/format=xlsx"
file = pd.ExcelFile(f"{url_base}{url_id}{url_e}")  
with pd.ExcelFile(file) as xls:  
    names_df = pd.read_excel(xls, "algorithms abbreviations", header=0)
    
#ignoring warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, message=".*utcnow.*")
now = datetime.datetime.utcnow()

# %%
names_df["Algorithm name"] = names_df["Algorithm name"].str.lower()
names_df["Abbreviations"] = names_df["Abbreviations"].str.lower()
names_df["Abbreviations"] = names_df["Abbreviations"].str.strip()
names_df
# Out:
#                                         Algorithm name Abbreviations
# 0                          artificial algae algorithm            aaa
# 1              adaboost with locally weighted learning         ablwl
# 2                              ant-colony optimization           aco
# 3                          auto encoder based approach          aeba
# 4    adaptive network-based fuzzy inference system ...         anfis
# ..                                                 ...           ...
# 169                                 sentiment reasoner         vader
# 170  very deep convolutional networks for large sca...        vggnet
# 171                           wind driven optimization           wdo
# 172                          xlnet neural network mode         xlnet
# 173                            xy- fused querynetworks           xyf
#
# [174 rows x 2 columns]

# %%
merged_df = pd.merge(algo_df, names_df, 
                     left_on=algo_df['Algorithms'], 
                     right_on=names_df["Abbreviations"], how='left')[["EID", "Algorithms", "Algorithm name", "Abbreviations"]]
merged_df.head(50)
# Out:
#                    EID       Algorithms  \
# 0   2-s2.0-85121255385              aaa
# 1   2-s2.0-85102000803            ablwl
# 2   2-s2.0-85042656860              aco
# 3   2-s2.0-85038906891              aco
# 4   2-s2.0-85084937718              aco
# 5   2-s2.0-85079043107         adaboost
# 6   2-s2.0-85143803463    adaboost, knn
# 7   2-s2.0-85133285340  adam optimizaer
# 8   2-s2.0-85150761407   adam optimizer
# 9   2-s2.0-85122798542             aeba
# 10  2-s2.0-85085071705            anfis
# 11  2-s2.0-85105062075            anfis
# 12  2-s2.0-85088160474            anfis
# 13  2-s2.0-85144595872            anfis
# 14  2-s2.0-84911124175            anfis
# 15  2-s2.0-85104590664            anfis
# 16  2-s2.0-85145892014            anfis
# 17  2-s2.0-85120852953            anfis
# 18  2-s2.0-84981287463            anfis
# 19  2-s2.0-85140628858            anfis
# 20  2-s2.0-85116003550            anfis
# 21  2-s2.0-85062961483            anfis
# 22  2-s2.0-85056208206            anfis
# 23  2-s2.0-85141451707            anfis
# 24  2-s2.0-85153562963            anfis
# 25  2-s2.0-85121369927            anfis
# 26  2-s2.0-46449123911            anfis
# 27  2-s2.0-85180647853            anfis
# 28  2-s2.0-85053459902            anfis
# 29  2-s2.0-85093695276            anfis
# 30  2-s2.0-85059813402            anfis
# 31  2-s2.0-85138682845            anfis
# 32  2-s2.0-84956600641              ann
# 33  2-s2.0-85180857959              ann
# 34  2-s2.0-85110520943              ann
# 35  2-s2.0-85174818561              ann
# 36  2-s2.0-85144871876              ann
# 37  2-s2.0-85132216491              ann
# 38  2-s2.0-85115278148              ann
# 39  2-s2.0-85129566278              ann
# 40  2-s2.0-85125664510              ann
# 41  2-s2.0-85100587143              ann
# 42  2-s2.0-84874029300              ann
# 43  2-s2.0-85110834711              ann
# 44  2-s2.0-85060456132              ann
# 45  2-s2.0-85143764591              ann
# 46  2-s2.0-85123255437              ann
# 47  2-s2.0-85149854857              ann
# 48  2-s2.0-85091383571              ann
# 49  2-s2.0-85063063103              ann
#
#                                        Algorithm name
# 0                         artificial algae algorithm
# 1             adaboost with locally weighted learning
# 2                             ant-colony optimization
# 3                             ant-colony optimization
# 4                             ant-colony optimization
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                         auto encoder based approach
# 10  adaptive network-based fuzzy inference system ...
# 11  adaptive network-based fuzzy inference system ...
# 12  adaptive network-based fuzzy inference system ...
# 13  adaptive network-based fuzzy inference system ...
# 14  adaptive network-based fuzzy inference system ...
# 15  adaptive network-based fuzzy inference system ...
# 16  adaptive network-based fuzzy inference system ...
# 17  adaptive network-based fuzzy inference system ...
# 18  adaptive network-based fuzzy inference system ...
# 19  adaptive network-based fuzzy inference system ...
# 20  adaptive network-based fuzzy inference system ...
# 21  adaptive network-based fuzzy inference system ...
# 22  adaptive network-based fuzzy inference system ...
# 23  adaptive network-based fuzzy inference system ...
# 24  adaptive network-based fuzzy inference system ...
# 25  adaptive network-based fuzzy inference system ...
# 26  adaptive network-based fuzzy inference system ...
# 27  adaptive network-based fuzzy inference system ...
# 28  adaptive network-based fuzzy inference system ...
# 29  adaptive network-based fuzzy inference system ...
# 30  adaptive network-based fuzzy inference system ...
# 31  adaptive network-based fuzzy inference system ...
# 32                          artificial neural network
# 33                          artificial neural network
# 34                          artificial neural network
# 35                          artificial neural network
# 36                          artificial neural network
# 37                          artificial neural network
# 38                          artificial neural network
# 39                          artificial neural network
# 40                          artificial neural network
# 41                          artificial neural network
# 42                          artificial neural network
# 43                          artificial neural network
# 44                          artificial neural network
# 45                          artificial neural network
# 46                          artificial neural network
# 47                          artificial neural network
# 48                          artificial neural network
# 49                          artificial neural network

# %% [markdown]
# ## Role of AI

# %%
role_df = df.loc[:, ["EID", "Role of AI"]]
role_df = separating(role_df, "Role of AI", "AI Role")
role_df = role_df.sort_values(by="AI Role", ascending=True).reset_index(drop=True)

# %%
role_df["AI Role"].unique()
# Out:
# array(['a.i integrated in products', 'accelerated experimentation', 'all',
#        'classification', 'communication infraestructure', 'data mining',
#        'data mining and remote sensing', 'decision making',
#        'fast approximate simulation', 'forecasting',
#        'increase effectiveness of blended learning',
#        'managing system data', 'maximizing power generation', 'overall',
#        'performance optimization', 'planning sustainable infrastructure',
#        'predictive maintainance', 'predictive maintaionance',
#        'predictive maintenance', 'reducing emissions', 'security',
#        'simulation', 'supply and demand prediction',
#        'system optimization', 'system optimization?',
#        'system optimzation', 'systemt optimization', nan], dtype=object)
