# %%
import pandas as pd
import json

# %%
## Load configuration
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# %% [markdown]
# ## Importing excel sheet from Google Drive

# %%
# https://docs.google.com/spreadsheets/d/1Yu0SF_99P_Qx3_-PZgxR78mUeFMsp5JB/edit?usp=sharing&ouid=100169992130227570752&rtpof=true&sd=true
url_id = config['url_id']
url_base = "https://docs.google.com/spreadsheets/d/"
url_e = "export/format=xlsx"
file = pd.ExcelFile(f"{url_base}{url_id}{url_e}")  
with pd.ExcelFile(file) as xls:  
    df = pd.read_excel(xls, "cleaner table", header=0)
    df = df.iloc[:,:44]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Authors                                  868 non-null    object
#  1   Author full names                        856 non-null    object
#  2   Author(s) ID                             855 non-null    object
#  3   Title                                    867 non-null    object
#  4   Year                                     868 non-null    int64
#  5   Source title                             868 non-null    object
#  6   Volume                                   836 non-null    float64
#  7   Issue                                    509 non-null    object
#  8   Art. No.                                 518 non-null    object
#  9   Page start                               351 non-null    object
#  10  Page end                                 351 non-null    object
#  11  Page count                               350 non-null    float64
#  12  Cited by                                 868 non-null    int64
#  13  DOI                                      862 non-null    object
#  14  Link                                     782 non-null    object
#  15  Author Keywords                          621 non-null    object
#  16  Index Keywords                           565 non-null    object
#  17  Abstract                                 837 non-null    object
#  18  Document Type                            857 non-null    object
#  19  Publication Stage                        857 non-null    object
#  20  Open Access                              550 non-null    object
#  21  Source                                   857 non-null    object
#  22  EID                                      868 non-null    object
#  23  SDG                                      868 non-null    int64
#  24  AI (yes/no)                              868 non-null    int64
#  25  Sustainability (yes/no)                  868 non-null    int64
#  26  Type of AI                               868 non-null    object
#  27  Algorithm(s) used                        865 non-null    object
#  28  Method (1) vs. study object (2)          862 non-null    object
#  29  AI as buzzword? (0/1)                    868 non-null    int64
#  30  Core topic                               868 non-null    object
#  31  Role of AI                               581 non-null    object
#  32  Means (1) vs. end (2)                    861 non-null    object
#  33  sustainability definition                424 non-null    object
#  34  Sus_lvl                                  868 non-null    object
#  35  empirical/conceptual/review              868 non-null    object
#  36  spatial scale                            457 non-null    object
#  37  snapshot in time vs. longitudinal study  525 non-null    object
#  38  temporal scale (past, present, future)   528 non-null    object
#  39  qualitative/quantitative/mixed methods   532 non-null    object
#  40  location of the study (country)          370 non-null    object
#  41  dataset used                             451 non-null    object
#  42  first_author_country                     868 non-null    object
#  43  policy recommendations (1/0)             868 non-null    int64
# dtypes: float64(2), int64(7), object(35)
# memory usage: 298.5+ KB

# %% [markdown]
# ## Converting columns to boolean

# %%
columns_to_boolean = ["AI (yes/no)", 
            "Sustainability (yes/no)", 
            "AI as buzzword? (0/1)",
            "policy recommendations (1/0)"]

# %%
df[columns_to_boolean] = df[columns_to_boolean].astype('bool')

# %%
df
# Out:
#                                                Authors  \
# 0                      Thiebes S.; Lins S.; Sunyaev A.
# 1                        Ho J.-H.; Lee G.-G.; Lu M.-T.
# 2                                          Bartmann M.
# 3                                          Halsband A.
# 4    Raman R.; Kumar Nair V.; Nedungadi P.; Ray I.;...
# ..                                                 ...
# 863                           Zhang Y.; Ji Y.; Qian H.
# 864                                   Jang J.; Kyun S.
# 865  Kabukye J.K.; Namugga J.; Mpamani C.J.; Katumb...
# 866                           Deng M.; Liu Y.; Chen L.
# 867  Zhu X.; Yao Q.; Dai W.; Ji L.; Yao Y.; Pang B....
#
#                                      Author full names  \
# 0    Thiebes, Scott (56319399400); Lins, Sebastian ...
# 1    Ho, Juin-Hao (57218510909); Lee, Gwo-Guang (74...
# 2                       Bartmann, Marius (56512092600)
# 3                      Halsband, Aurélie (57562370000)
# 4    Raman, Raghu (36618183700); Kumar Nair, Vinith...
# ..                                                 ...
# 863  Zhang, Yang (57471054500); Ji, Yuanhui (572047...
# 864                          Jang, Jiyoung; Kyun, Suna
# 865  Kabukye, Johnblack K.; Namugga, Jane; Mpamani,...
# 866             Deng, Meizhen; Liu, Yimeng; Chen, Ling
# 867  Zhu, Xingce; Yao, Qiang; Dai, Wei; Ji, Lu; Yao...
#
#                                           Author(s) ID  \
# 0                56319399400; 56318996100; 24779131200
# 1                 57218510909; 7404852393; 55801461400
# 2                                             5.65E+10
# 3                                             5.76E+10
# 4    36618183700; 57647914700; 36069838600; 5883060...
# ..                                                 ...
# 863              57471054500; 57204776640; 55186013100
# 864                                                NaN
# 865  57205140187; 57201368167; 57403715300; 3623907...
# 866              58606568400; 58605588800; 57700546300
# 867  58221931100; 55588525000; 56366749800; 5684438...
#
#                                                  Title  Year  \
# 0                  Trustworthy artificial intelligence  2021
# 1    Exploring the implementation of a legal AI bot...  2020
# 2    The Ethics of AI-Powered Climate Nudging—How M...  2022
# 3         Sustainable AI and Intergenerational Justice  2022
# 4    Darkweb research: Past, present, and future tr...  2023
# ..                                                 ...   ...
# 863  Progress in thermodynamic simulation and syste...  2021
# 864  An Innovative Career Management Platform Empow...  2022
# 865  Implementing Smartphone-Based Telemedicine for...  2023
# 866  AI-driven innovation in ethnic clothing design...  2023
# 867  Cervical cancer screening aided by artificial ...  2023
#
#                                           Source title  Volume Issue Art. No.  \
# 0                                   Electronic Markets    31.0     2      NaN
# 1                         Sustainability (Switzerland)    12.0    15     5991
# 2                         Sustainability (Switzerland)    14.0     9     5153
# 3                         Sustainability (Switzerland)    14.0     7     3922
# 4                                              Heliyon     9.0    11   e22269
# ..                                                 ...     ...   ...      ...
# 863                         Green Chemical Engineering     2.0     3      NaN
# 864  Journal of Logistics, Informatics and Service ...     9.0     1      NaN
# 865               Journal of Medical Internet Research    25.0     1   e45132
# 866                        Electronic Research Archive    31.0     9      NaN
# 867          Bulletin of the World Health Organization   101.0     6      NaN
#
#     Page start  ... Sus_lvl  empirical/conceptual/review  spatial scale  \
# 0          447  ...    weak                   conceptual            NaN
# 1          NaN  ...    weak                    empirical       national
# 2          NaN  ...    weak                   conceptual            NaN
# 3          NaN  ...  strong                   conceptual            NaN
# 4          NaN  ...  strong                       review            NaN
# ..         ...  ...     ...                          ...            ...
# 863        266  ...    weak                       Review            NaN
# 864        274  ...    weak                   conceptual            NaN
# 865        NaN  ...    weak                    empirical       regional
# 866       5793  ...    weak                    empirical          local
# 867        381  ...    weak                    empirical       regional
#
#     snapshot in time vs. longitudinal study  \
# 0                                       NaN
# 1                                  snapshot
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 863                                     NaN
# 864                                     NaN
# 865                                snapshot
# 866                                snapshot
# 867                                snapshot
#
#     temporal scale (past, present, future)  \
# 0                                      NaN
# 1                                  present
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 863                                    NaN
# 864                                    NaN
# 865                                present
# 866                                present
# 867                                present
#
#     qualitative/quantitative/mixed methods location of the study (country)  \
# 0                                      NaN                             NaN
# 1                             quantitative                          Taiwan
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                    mixed                             NaN
# ..                                     ...                             ...
# 863                                    NaN                             NaN
# 864                                    NaN                             NaN
# 865                            qualitative                          Uganda
# 866                                  mixed                          Biasha
# 867                           quantitative                           China
#
#     dataset used first_author_country policy recommendations (1/0)
# 0            NaN              Germany                        False
# 1         survey               Taiwan                        False
# 2            NaN              Germany                        False
# 3            NaN              Germany                        False
# 4            NaN                India                         True
# ..           ...                  ...                          ...
# 863          NaN                China                        False
# 864          NaN    South South Korea                        False
# 865          NaN               Sweden                        False
# 866          NaN                China                        False
# 867          NaN                China                        False
#
# [868 rows x 44 columns]

# %% [markdown]
# ## Selecting articles metadata

# %%
articles_df = df.loc[:,["EID", "Title", "Year",
                        "SDG", "Source title", 
                        "Cited by", "DOI", 
                        "Abstract", "Author Keywords", "Index Keywords", 
                        "AI (yes/no)", "Sustainability (yes/no)" ]]
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EID                      868 non-null    object
#  1   Title                    867 non-null    object
#  2   Year                     868 non-null    int64
#  3   SDG                      868 non-null    int64
#  4   Source title             868 non-null    object
#  5   Cited by                 868 non-null    int64
#  6   DOI                      862 non-null    object
#  7   Abstract                 837 non-null    object
#  8   Author Keywords          621 non-null    object
#  9   Index Keywords           565 non-null    object
#  10  AI (yes/no)              868 non-null    int64
#  11  Sustainability (yes/no)  868 non-null    int64
# dtypes: int64(5), object(7)
# memory usage: 81.5+ KB

# %%
articles_df[["AI (yes/no)", "Sustainability (yes/no)"]] = articles_df[["AI (yes/no)",
                                                                       "Sustainability (yes/no)"]].astype('bool')

# %% [markdown]
# ## Function to separate values in the same cell

# %%
def separating(df, old_column, new_column):
    df[new_column] = df[old_column].str.split(';')
    df = df.explode(new_column)
    df = df.drop(columns=old_column).reset_index(drop=True)
    df[new_column] = df[new_column].str.strip()
    return df

# %%
df_ai = df.loc[:, ["EID", "Type of AI"]]

# %%
new_df = separating(df_ai, "Type of AI", "AI_type")
new_df
# Out:
#                      EID                        AI_type
# 0     2-s2.0-85148853990                        overall
# 1     2-s2.0-85168710066                        overall
# 2     2-s2.0-85174445734                        overall
# 3     2-s2.0-85139602753                        overall
# 4     2-s2.0-85185331385                            nlp
# ...                  ...                            ...
# 1069  2-s2.0-85174748358               machine learning
# 1070  2-s2.0-85171645006  unsupervised machine learning
# 1071  2-s2.0-85171645006                            nlp
# 1072  2-s2.0-85171645006                  deep learning
# 1073  2-s2.0-85160969682                        overall
#
# [1074 rows x 2 columns]

# %%
new_df["AI_type"].unique()
# Out:
# array(['overall', 'nlp', 'deep learning', 'supervised machine learning',
#        'machine learning', 'IDSS', 'unspervised machine learning',
#        'evolutionary algorithm', 'fuzzy logic',
#        'unsupervised machine learning', 'Google Earth Engine',
#        'genetic algorithm', 'reinforcement learning', 'Symbolic AI',
#        'MAS', 'evolutionary algorithms', 'Edge AI', 'Fuzzy Logic',
#        'Machine Learning', 'MCDM AI', 'GMDH', 'deep learnimg',
#        'evolutionary algorithsm', 'evolutionary algoriths',
#        'artificial neural network', 'EAI', 'LLM', 'geospatial AI',
#        'generative AI', 'unsupervisde machine learning', 'quantum AI',
#        'explainable AI', 'supervised machine learningmachine learning',
#        'machine leraning', 'Fuzzy logic'], dtype=object)

# %%
new_df.loc[244, "AI_type"]
# Out:
# 'deep learning'
